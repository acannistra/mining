# %%
import pandas as pd
import geopandas as gpd
import folium
from shapely.geometry import Point
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline

mines = pd.read_csv("mines_data/rdbms-tab-all/MRDS.txt", sep='\t').set_index("dep_id")
_comm = pd.read_csv("mines_data/rdbms-tab-all/Commodity.txt", sep='\t').set_index('dep_id')
mines = mines.join(_comm.drop('i', axis=1))

# %% [markdown]
# ---
# ## Economics of Mining
# ### 1. Land Ownership:

# %%
land_status = pd.read_csv("mines_data/rdbms-tab-all/Land_status.txt", sep='\t').set_index('dep_id').drop('i', axis=1)
mines_owners = mines.join(land_status, how='left', rsuffix="__")
mines_owners.head(5)
# Out:
#               i                 name    dev_stat  \
# dep_id
# 10000001  63923     Lookout Prospect  Occurrence
# 10000001  63923     Lookout Prospect  Occurrence
# 10000001  63923     Lookout Prospect  Occurrence
# 10000002  42634  Lucky Find Prospect  Occurrence
# 10000002  42634  Lucky Find Prospect  Occurrence
#
#                                                         url code_list  \
# dep_id
# 10000001  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    CU AU
# 10000001  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    CU AU
# 10000001  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    CU AU
# 10000002  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    CU AU
# 10000002  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    CU AU
#
#           longitude  latitude  line  commod code          ...           \
# dep_id                                                    ...
# 10000001 -132.14344  55.05612   1.0  Copper   CU          ...
# ...

# %%
top10groupnames = mines_owners.groupby("commod_group").count()['i'].sort_values(ascending=False)[:10].keys()
top10groups = mines_owners[mines_owners.commod_group.isin(top10groupnames)]

# %%
sns.set(font_scale=1.2)
sns.factorplot(y="land_st", kind='count', col="commod_group", data=top10groups, col_wrap=5, col_order=top10groupnames)
plt.savefig("landtypetop10.png")

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-b56e0ba44ab4> in <module>()
# ----> 1 g = g.map(sns.countplot, x='land_st')
#
# /Users/tony/miniconda3/lib/python3.5/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     701
#     702             # Get the current axis
# --> 703             ax = self.facet_axis(row_i, col_j)
#     704
#     705             # Decide what color to plot with
#
# /Users/tony/miniconda3/lib/python3.5/site-packages/seaborn/axisgrid.py in facet_axis(self, row_i, col_j)
#     832
#     833         # Get a reference to the axes object we want, and make it active
# --> 834         plt.sca(ax)
#     835         return ax
#     836
#
# /Users/tony/miniconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in sca(ax)
#     927             m.canvas.figure.sca(ax)
#     928             return
# ...
